# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15 
state_size = 4
num_classes = 2
echo_step = 3 
batch_size = 5 # number of sample trained in a iteration
num_batches = total_series_length//batch_size//truncated_backprop_length

# %%
def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

# %%
batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])


# Please refers to 
# https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/LSTMStateTuple
cell_state = tf.placeholder(tf.float32, [batch_size, state_size])
hidden_state = tf.placeholder(tf.float32, [batch_size, state_size])
init_state = tf.contrib.rnn.LSTMStateTuple(cell_state, hidden_state)
print("init_state created by LSTMStateTuple:", init_state)
# Out:
# init_state created by LSTMStateTuple: LSTMStateTuple(c=<tf.Tensor 'Placeholder_2:0' shape=(5, 4) dtype=float32>, h=<tf.Tensor 'Placeholder_3:0' shape=(5, 4) dtype=float32>)

# %%
# W and b is useless in this example, because the tensorflow will create the 
# weight for the variable in the cell.
W = tf.Variable(np.random.rand(state_size+1, state_size), dtype=tf.float32)
b = tf.Variable(np.zeros((1, state_size)), dtype=tf.float32)


# W2 and b2 is needed as we will use this to calculate the logits of the outputs
W2 = tf.Variable(np.random.rand(state_size, num_classes), dtype=tf.float32)
b2 = tf.Variable(np.zeros((1, num_classes)), dtype=tf.float32)

# %%
# batchX_placeholder is in shape of (batch_size, truncated_backprop_length)
# Let's say batch_size=5, and truncated_backprop_length=15
# If we unstack the batchX_placeholder, it will have 15 of (5,) tensor.
# The rnn is trained based on this 5 batches with 15 timesteps each

# inputs_series = tf.unstack(batchX_placeholder, axis=1)
# ^ the above code is replaced by tf.split command
# tf.split will split the batchX_placeholder evenly into truncated_backprop_length
# number of tensor along the 1st-axis
# e.g. batchX_placeholder is of shape (5, 30) and truncated_backprop_length is 3
# then, there will be 10 tensors of shape (5, 3)
inputs_series = tf.split(batchX_placeholder, 15, axis=1)
labels_series = tf.unstack(batchY_placeholder, axis=1)

print(inputs_series)
# Out:
# [<tf.Tensor 'split:0' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:1' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:2' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:3' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:4' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:5' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:6' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:7' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:8' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:9' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:10' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:11' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:12' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:13' shape=(5, 1) dtype=float32>, <tf.Tensor 'split:14' shape=(5, 1) dtype=float32>]

# %%
# This is basically the forward pass in the RNN.
# For each input in the inputs_series, we concatenate it with the state value.
# Then, we apply the same weights W and biases b on each of these input and
# find the corresponding state value in this time series. 

if False: # for reference only
    current_state = init_state
    states_series = []

    for current_input in inputs_series:
        # (5,) -> (5,1) so as to concatenate with the state
        current_input = tf.reshape(current_input, [batch_size, 1])

        # Calculate the sum of affine transform
        # By concatenating those two tensors you will only use one matrix 
        # multiplication.
        input_and_state_concatenated = tf.concat([current_input, current_state], 1)

        next_state = tf.tanh(tf.matmul(input_and_state_concatenated, W) + b)
        states_series.append(next_state)
        current_state = next_state

# %%
# forward pass implemented with the help of tensorflow
# This code resembles the above 
# cell = tf.contrib.rnn.BasicRNNCell(num_units=state_size)

cell = tf.contrib.rnn.BasicLSTMCell(num_units=state_size, state_is_tuple=True)
states_series, current_state = tf.contrib.rnn.static_rnn(cell, inputs_series, init_state)

print(states_series)
# Out:
# [<tf.Tensor 'rnn/basic_lstm_cell/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_1/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_2/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_3/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_4/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_5/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_6/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_7/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_8/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_9/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_10/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_11/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_12/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_13/mul_2:0' shape=(5, 4) dtype=float32>, <tf.Tensor 'rnn/basic_lstm_cell_14/mul_2:0' shape=(5, 4) dtype=float32>]

# %%
# Calculating loss

# This calculate the logits of the series X fed intp the rnn by multiplying
# the hidden state neurons with weights and adding the biases. If the truncated
# length is of 15, then the length of logits series is also of 15.
logits_series = [tf.matmul(state, W2) + b2 for state in states_series]
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)\
         for logits, labels in zip(logits_series, labels_series)]

total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

# %%
# visualizing the training

def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = \
        np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = \
        np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list=[]
    
    for epoch_idx in range(num_epochs):
        x,y = generateData()
        #_current_state = np.zeros((batch_size, state_size))
        _current_cell_state = np.zeros((batch_size, state_size))
        _current_hidden_state = np.zeros((batch_size, state_size))
        
        print("New data, epoch", epoch_idx)
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length
            
            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]
            
            _total_loss, _train_step, _current_state, _predictions_series = \
            sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder: batchX,
                    batchY_placeholder: batchY,
                    cell_state: _current_cell_state,
                    hidden_state: _current_hidden_state,
                }
            )
            # current_state is a tuple of (cell_state, hidden_state)
            _current_cell_state, _current_hidden_state = _current_state
            
            loss_list.append(_total_loss)
            
            if batch_idx%100 == 0:
                print("Step",batch_idx,"Loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# New data, epoch 0
# Step 0 Loss 0.689841
# Step 100 Loss 0.59938
# Step 200 Loss 0.373447
# Step 300 Loss 0.292394
# Step 400 Loss 0.178763
# Step 500 Loss 0.0173175
# Step 600 Loss 0.00868454
# New data, epoch 1
# Step 0 Loss 0.349732
# Step 100 Loss 0.00452724
# Step 200 Loss 0.00316158
# Step 300 Loss 0.00236901
# Step 400 Loss 0.00230271
# Step 500 Loss 0.00209542
# Step 600 Loss 0.00144861
# New data, epoch 2
# Step 0 Loss 0.537539
# Step 100 Loss 0.00124516
# Step 200 Loss 0.00131492
# Step 300 Loss 0.00123089
# Step 400 Loss 0.00113203
# Step 500 Loss 0.00123177
# Step 600 Loss 0.00103243
# New data, epoch 3
# Step 0 Loss 0.619723
# Step 100 Loss 0.00112797
# Step 200 Loss 0.000862249
# Step 300 Loss 0.000754441
# Step 400 Loss 0.000747091
# Step 500 Loss 0.000606868
# Step 600 Loss 0.000699063
# New data, epoch 4
# Step 0 Loss 0.63259
# Step 100 Loss 0.000603935
# Step 200 Loss 0.000743906
# Step 300 Loss 0.00052439
# Step 400 Loss 0.000531775
# Step 500 Loss 0.000544002
# Step 600 Loss 0.000507978
# New data, epoch 5
# Step 0 Loss 0.728764
# Step 100 Loss 0.00040073
# Step 200 Loss 0.000559231
# Step 300 Loss 0.000342907
# Step 400 Loss 0.000435947
# Step 500 Loss 0.000464762
# Step 600 Loss 0.000437059
# New data, epoch 6
# Step 0 Loss 0.59427
# Step 100 Loss 0.000511279
# Step 200 Loss 0.000382062
# Step 300 Loss 0.000387084
# Step 400 Loss 0.00037131
# Step 500 Loss 0.000333088
# Step 600 Loss 0.000345047
# New data, epoch 7
# Step 0 Loss 0.780493
# Step 100 Loss 0.00036459
# Step 200 Loss 0.000387246
# Step 300 Loss 0.000327105
# Step 400 Loss 0.000459054
# Step 500 Loss 0.000359721
# Step 600 Loss 0.000378701
# New data, epoch 8
# Step 0 Loss 0.877244
# Step 100 Loss 0.000272461
# Step 200 Loss 0.000283498
# Step 300 Loss 0.000303702
# Step 400 Loss 0.000302377
# Step 500 Loss 0.000321772
# Step 600 Loss 0.000293038
# New data, epoch 9
# Step 0 Loss 0.448743
# Step 100 Loss 0.000501516
# Step 200 Loss 0.000459749
# Step 300 Loss 0.000344589
# Step 400 Loss 0.000310842
# Step 500 Loss 0.000254768
# Step 600 Loss 0.000246946
# New data, epoch 10
# Step 0 Loss 0.765287
# Step 100 Loss 0.000295314
# Step 200 Loss 0.000325159
# Step 300 Loss 0.000293701
# Step 400 Loss 0.000294381
# Step 500 Loss 0.000270634
# Step 600 Loss 0.000239713
# New data, epoch 11
# Step 0 Loss 0.550674
# Step 100 Loss 0.000292755
# Step 200 Loss 0.000279684
# Step 300 Loss 0.000303429
# Step 400 Loss 0.000238317
# Step 500 Loss 0.00021876
# Step 600 Loss 0.00029843
# New data, epoch 12
# Step 0 Loss 0.269486
# Step 100 Loss 0.00023434
# Step 200 Loss 0.000235348
# Step 300 Loss 0.000176506
# Step 400 Loss 0.00022241
# Step 500 Loss 0.000264539
# Step 600 Loss 0.000210161
# New data, epoch 13
# Step 0 Loss 0.795179
# Step 100 Loss 0.000226767
# Step 200 Loss 0.000250674
# Step 300 Loss 0.000203994
# Step 400 Loss 0.000160341
# Step 500 Loss 0.000192774
# Step 600 Loss 0.000158286
# New data, epoch 14
# Step 0 Loss 0.53538
# Step 100 Loss 0.000251486
# Step 200 Loss 0.000238118
# Step 300 Loss 0.000240062
# Step 400 Loss 0.000185946
# Step 500 Loss 0.00022497
# Step 600 Loss 0.000142249
# New data, epoch 15
# Step 0 Loss 1.09838
# Step 100 Loss 0.00031697
# Step 200 Loss 0.000251751
# Step 300 Loss 0.000229499
# Step 400 Loss 0.000289707
# Step 500 Loss 0.000231313
# Step 600 Loss 0.000195488
# New data, epoch 16
# Step 0 Loss 0.972047
# Step 100 Loss 0.000442387
# Step 200 Loss 0.000330137
# Step 300 Loss 0.000327925
# Step 400 Loss 0.000255269
# Step 500 Loss 0.000268558
# Step 600 Loss 0.000244621
# New data, epoch 17
# Step 0 Loss 0.719659
# Step 100 Loss 0.000271278
# Step 200 Loss 0.00031522
# Step 300 Loss 0.000308265
# Step 400 Loss 0.000255524
# Step 500 Loss 0.000309888
# Step 600 Loss 0.000248681
# New data, epoch 18
# Step 0 Loss 0.220224
# Step 100 Loss 0.000209486
# Step 200 Loss 0.000207989
# Step 300 Loss 0.000212098
# Step 400 Loss 0.000199717
# Step 500 Loss 0.000257385
# Step 600 Loss 0.000196864
# New data, epoch 19
# Step 0 Loss 0.572723
# Step 100 Loss 0.000206659
# Step 200 Loss 0.000212766
# Step 300 Loss 0.000249851
# Step 400 Loss 0.000220792
# Step 500 Loss 0.000223164
# Step 600 Loss 0.00017753
# New data, epoch 20
# Step 0 Loss 0.560343
# Step 100 Loss 0.000200099
# Step 200 Loss 0.000240244
# Step 300 Loss 0.000175887
# Step 400 Loss 0.000188096
# Step 500 Loss 0.000183725
# Step 600 Loss 0.000203049
# New data, epoch 21
# Step 0 Loss 0.719482
# Step 100 Loss 0.000169449
# Step 200 Loss 0.000194856
# Step 300 Loss 0.000158502
# Step 400 Loss 0.000211518
# Step 500 Loss 0.000204835
# Step 600 Loss 0.000212198
# New data, epoch 22
# Step 0 Loss 0.416273
# Step 100 Loss 0.000162774
# Step 200 Loss 0.000263339
# Step 300 Loss 0.000208065
# Step 400 Loss 0.000158513
# Step 500 Loss 0.000162377
# Step 600 Loss 0.000157891
# New data, epoch 23
# Step 0 Loss 0.702924
# Step 100 Loss 0.000167685
# Step 200 Loss 0.000179576
# Step 300 Loss 0.000144601
# Step 400 Loss 0.000182389
# Step 500 Loss 0.000148113
# Step 600 Loss 0.000158247
# New data, epoch 24
# Step 0 Loss 0.540926
# Step 100 Loss 0.000168337
# Step 200 Loss 0.00016883
# Step 300 Loss 0.000171428
# Step 400 Loss 0.000146454
# Step 500 Loss 0.000144194
# Step 600 Loss 0.000159511
# New data, epoch 25
# Step 0 Loss 0.497386
# Step 100 Loss 0.000234776
# Step 200 Loss 0.000166093
# Step 300 Loss 0.000159961
# Step 400 Loss 0.0001459
# Step 500 Loss 0.000136947
# Step 600 Loss 0.000163283
# New data, epoch 26
# Step 0 Loss 0.477939
# Step 100 Loss 0.000133871
# Step 200 Loss 0.00014983
# Step 300 Loss 0.00017624
# Step 400 Loss 0.000161485
# Step 500 Loss 0.000141095
# Step 600 Loss 0.000142172
# New data, epoch 27
# Step 0 Loss 0.460397
# Step 100 Loss 0.000138617
# Step 200 Loss 0.000135837
# Step 300 Loss 0.000133279
# Step 400 Loss 0.000138662
# Step 500 Loss 0.000130091
# Step 600 Loss 0.000157326
# New data, epoch 28
# Step 0 Loss 0.783895
# Step 100 Loss 0.00015253
# Step 200 Loss 0.000165101
# Step 300 Loss 0.000151764
# Step 400 Loss 0.000127185
# Step 500 Loss 0.000140206
# Step 600 Loss 0.000106705
# New data, epoch 29
# Step 0 Loss 0.61165
# Step 100 Loss 0.000187454
# Step 200 Loss 0.000145381
# Step 300 Loss 0.00013392
# Step 400 Loss 0.000139852
# Step 500 Loss 0.000177916
# Step 600 Loss 0.000144458
# New data, epoch 30
# Step 0 Loss 0.615272
# Step 100 Loss 0.000128685
# Step 200 Loss 0.000139036
# Step 300 Loss 0.000141379
# Step 400 Loss 0.000122455
# Step 500 Loss 0.00015824
# Step 600 Loss 0.000113312
# New data, epoch 31
# Step 0 Loss 0.756869
# Step 100 Loss 0.000189933
# Step 200 Loss 0.000208396
# Step 300 Loss 0.000187783
# Step 400 Loss 0.000151341
# Step 500 Loss 0.000161626
# Step 600 Loss 0.000163572
# New data, epoch 32
# Step 0 Loss 0.512311
# Step 100 Loss 0.000156471
# Step 200 Loss 0.000136595
# Step 300 Loss 0.000150428
# Step 400 Loss 0.000121556
# Step 500 Loss 0.000116561
# Step 600 Loss 0.000161046
# New data, epoch 33
# Step 0 Loss 0.680476
# Step 100 Loss 0.000155029
# Step 200 Loss 0.000143934
# Step 300 Loss 0.000119086
# Step 400 Loss 0.000123526
# Step 500 Loss 0.000123675
# Step 600 Loss 0.000125118
# New data, epoch 34
# Step 0 Loss 0.581421
# Step 100 Loss 0.000134661
# Step 200 Loss 0.000135286
# Step 300 Loss 0.000139964
# Step 400 Loss 0.000134417
# Step 500 Loss 0.000112794
# Step 600 Loss 0.00012915
# New data, epoch 35
# Step 0 Loss 0.321684
# Step 100 Loss 0.00014063
# Step 200 Loss 0.000128601
# Step 300 Loss 0.000119067
# Step 400 Loss 0.000143042
# Step 500 Loss 0.000141469
# Step 600 Loss 0.00011491
# New data, epoch 36
# Step 0 Loss 0.463869
# Step 100 Loss 0.000127227
# Step 200 Loss 0.000132397
# Step 300 Loss 0.000122685
# Step 400 Loss 0.000142931
# Step 500 Loss 0.000125933
# Step 600 Loss 0.00013082
# New data, epoch 37
# Step 0 Loss 0.78568
# Step 100 Loss 0.00015145
# Step 200 Loss 0.000133003
# Step 300 Loss 0.000131041
# Step 400 Loss 0.00012359
# Step 500 Loss 0.000132791
# Step 600 Loss 0.00013056
# New data, epoch 38
# Step 0 Loss 0.426813
# Step 100 Loss 0.000107615
# Step 200 Loss 0.000126256
# Step 300 Loss 0.000116596
# Step 400 Loss 0.000118791
# Step 500 Loss 0.00010637
# Step 600 Loss 0.000128076
# New data, epoch 39
# Step 0 Loss 0.227651
# Step 100 Loss 0.000100064
# Step 200 Loss 0.000104353
# Step 300 Loss 0.000110321
# Step 400 Loss 0.000117474
# Step 500 Loss 0.000100821
# Step 600 Loss 0.000110357
# New data, epoch 40
# Step 0 Loss 0.631432
# Step 100 Loss 0.000141273
# Step 200 Loss 0.000117891
# Step 300 Loss 0.000124228
# Step 400 Loss 0.000117822
# Step 500 Loss 0.000107911
# Step 600 Loss 9.10266e-05
# New data, epoch 41
# Step 0 Loss 0.535258
# Step 100 Loss 0.000120558
# Step 200 Loss 0.000103994
# Step 300 Loss 0.000116953
# Step 400 Loss 0.000103885
# Step 500 Loss 0.000103425
# Step 600 Loss 0.000114328
# New data, epoch 42
# Step 0 Loss 0.454396
# Step 100 Loss 9.83609e-05
# Step 200 Loss 9.97317e-05
# Step 300 Loss 0.000116912
# Step 400 Loss 8.53904e-05
# Step 500 Loss 0.000112328
# Step 600 Loss 9.71222e-05
# New data, epoch 43
# Step 0 Loss 0.50321
# Step 100 Loss 0.000148481
# Step 200 Loss 0.000117226
# Step 300 Loss 0.000132832
# Step 400 Loss 0.000106239
# Step 500 Loss 9.27487e-05
# Step 600 Loss 0.000110886
# New data, epoch 44
# Step 0 Loss 0.291011
# Step 100 Loss 0.000104221
# Step 200 Loss 0.000126483
# Step 300 Loss 0.000118084
# Step 400 Loss 9.67588e-05
# Step 500 Loss 9.2205e-05
# Step 600 Loss 9.13994e-05
# New data, epoch 45
# Step 0 Loss 0.363146
# Step 100 Loss 0.00012785
# Step 200 Loss 0.000120337
# Step 300 Loss 9.53711e-05
# Step 400 Loss 0.000100473
# Step 500 Loss 0.000118572
# Step 600 Loss 9.70281e-05
# New data, epoch 46
# Step 0 Loss 0.692224
# Step 100 Loss 0.00011059
# Step 200 Loss 0.000111416
# Step 300 Loss 0.000139928
# Step 400 Loss 0.000107214
# Step 500 Loss 0.000124669
# Step 600 Loss 9.44082e-05
# New data, epoch 47
# Step 0 Loss 0.47514
# Step 100 Loss 0.000121131
# Step 200 Loss 0.000104066
# Step 300 Loss 0.000104278
# Step 400 Loss 0.000125449
# Step 500 Loss 9.66676e-05
# Step 600 Loss 0.000100664
# New data, epoch 48
# Step 0 Loss 0.715685
# Step 100 Loss 0.000142928
# Step 200 Loss 9.90465e-05
# Step 300 Loss 0.000111
# Step 400 Loss 9.34764e-05
# Step 500 Loss 0.00010635
# Step 600 Loss 0.000109425
# New data, epoch 49
# Step 0 Loss 0.606196
# Step 100 Loss 0.000112204
# Step 200 Loss 0.000126455
# Step 300 Loss 0.000124
# Step 400 Loss 0.000125592
# Step 500 Loss 0.000109303
# Step 600 Loss 0.000103487
# New data, epoch 50
# Step 0 Loss 0.502303
# Step 100 Loss 0.000139274
# Step 200 Loss 0.000123248
# Step 300 Loss 0.000110377
# Step 400 Loss 0.000122645
# Step 500 Loss 0.000127256
# Step 600 Loss 0.000114029
# New data, epoch 51
# Step 0 Loss 0.628132
# Step 100 Loss 0.000125454
# Step 200 Loss 0.000135457
# Step 300 Loss 0.000108547
# Step 400 Loss 0.000129469
# Step 500 Loss 0.000149463
# Step 600 Loss 0.000126971
# New data, epoch 52
# Step 0 Loss 0.326271
# Step 100 Loss 0.000131892
# Step 200 Loss 0.0001343
# Step 300 Loss 0.00011325
# Step 400 Loss 0.000101574
# Step 500 Loss 0.000109281
# Step 600 Loss 0.000121587
# New data, epoch 53
# Step 0 Loss 0.517982
# Step 100 Loss 0.000100555
# Step 200 Loss 0.000103525
# Step 300 Loss 0.000130519
# Step 400 Loss 9.84303e-05
# Step 500 Loss 0.000110126
# Step 600 Loss 0.000105438
# New data, epoch 54
# Step 0 Loss 0.573285
# Step 100 Loss 0.000125249
# Step 200 Loss 0.000125931
# Step 300 Loss 8.65382e-05
# Step 400 Loss 0.000115526
# Step 500 Loss 0.000119868
# Step 600 Loss 8.48522e-05
# New data, epoch 55
# Step 0 Loss 0.280404
# Step 100 Loss 0.000154063
# Step 200 Loss 0.000144043
# Step 300 Loss 9.5864e-05
# Step 400 Loss 0.000121078
# Step 500 Loss 0.000113901
# Step 600 Loss 0.000134122
# New data, epoch 56
# Step 0 Loss 0.350558
# Step 100 Loss 0.00014072
# Step 200 Loss 0.000102719
# Step 300 Loss 9.78851e-05
# Step 400 Loss 0.000118021
# Step 500 Loss 0.000121433
# Step 600 Loss 0.000127225
# New data, epoch 57
# Step 0 Loss 0.493342
# Step 100 Loss 9.61318e-05
# Step 200 Loss 9.86603e-05
# Step 300 Loss 0.000105219
# Step 400 Loss 9.71061e-05
# Step 500 Loss 0.000102836
# Step 600 Loss 0.000104419
# New data, epoch 58
# Step 0 Loss 0.561119
# Step 100 Loss 0.000124715
# Step 200 Loss 0.000102576
# Step 300 Loss 0.00011827
# Step 400 Loss 8.79512e-05
# Step 500 Loss 0.000126109
# Step 600 Loss 0.000121585
# New data, epoch 59
# Step 0 Loss 0.283071
# Step 100 Loss 9.49552e-05
# Step 200 Loss 0.000137219
# Step 300 Loss 0.000122451
# Step 400 Loss 9.52764e-05
# Step 500 Loss 0.000110597
# Step 600 Loss 0.000107416
# New data, epoch 60
# Step 0 Loss 0.62604
# Step 100 Loss 0.000153305
# Step 200 Loss 0.000102717
# Step 300 Loss 0.00013841
# Step 400 Loss 9.60249e-05
# Step 500 Loss 0.000112676
# Step 600 Loss 0.000121265
# New data, epoch 61
# Step 0 Loss 0.590711
# Step 100 Loss 0.000139533
# Step 200 Loss 9.83744e-05
# Step 300 Loss 0.000128618
# Step 400 Loss 0.000102354
# Step 500 Loss 0.00012577
# Step 600 Loss 9.09108e-05
# New data, epoch 62
# Step 0 Loss 0.525493
# Step 100 Loss 0.000103944
# Step 200 Loss 0.000116194
# Step 300 Loss 8.92126e-05
# Step 400 Loss 0.000118461
# Step 500 Loss 9.08414e-05
# Step 600 Loss 0.000100389
# New data, epoch 63
# Step 0 Loss 0.228663
# Step 100 Loss 0.000109246
# Step 200 Loss 0.000126577
# Step 300 Loss 9.95542e-05
# Step 400 Loss 9.67879e-05
# Step 500 Loss 0.000115213
# Step 600 Loss 9.74552e-05
# New data, epoch 64
# Step 0 Loss 0.427602
# Step 100 Loss 0.000129429
# Step 200 Loss 8.87201e-05
# Step 300 Loss 9.84639e-05
# Step 400 Loss 8.56136e-05
# Step 500 Loss 7.95336e-05
# Step 600 Loss 7.45599e-05
# New data, epoch 65
# Step 0 Loss 0.603793
# Step 100 Loss 0.000111922
# Step 200 Loss 0.000111114
# Step 300 Loss 0.000122562
# Step 400 Loss 8.35933e-05
# Step 500 Loss 8.45924e-05
# Step 600 Loss 9.48974e-05
# New data, epoch 66
# Step 0 Loss 0.422938
# Step 100 Loss 0.000145201
# Step 200 Loss 0.000189647
# Step 300 Loss 0.000145521
# Step 400 Loss 0.000124062
# Step 500 Loss 0.000131861
# Step 600 Loss 0.000131267
# New data, epoch 67
# Step 0 Loss 0.315293
# Step 100 Loss 0.000134252
# Step 200 Loss 0.000124185
# Step 300 Loss 0.000109095
# Step 400 Loss 0.000125142
# Step 500 Loss 9.83477e-05
# Step 600 Loss 8.13469e-05
# New data, epoch 68
# Step 0 Loss 0.522884
# Step 100 Loss 9.66719e-05
# Step 200 Loss 9.34178e-05
# Step 300 Loss 7.24084e-05
# Step 400 Loss 0.000103451
# Step 500 Loss 0.000112348
# Step 600 Loss 8.95239e-05
# New data, epoch 69
# Step 0 Loss 0.178155
# Step 100 Loss 0.000152315
# Step 200 Loss 0.000160511
# Step 300 Loss 9.94709e-05
# Step 400 Loss 8.1884e-05
# Step 500 Loss 9.46578e-05
# Step 600 Loss 7.56623e-05
# New data, epoch 70
# Step 0 Loss 0.433813
# Step 100 Loss 0.000108056
# Step 200 Loss 0.000104595
# Step 300 Loss 8.65783e-05
# Step 400 Loss 9.51191e-05
# Step 500 Loss 9.69421e-05
# Step 600 Loss 7.72796e-05
# New data, epoch 71
# Step 0 Loss 0.0865295
# Step 100 Loss 9.28213e-05
# Step 200 Loss 8.01064e-05
# Step 300 Loss 7.69511e-05
# Step 400 Loss 8.89782e-05
# Step 500 Loss 7.50283e-05
# Step 600 Loss 8.43151e-05
# New data, epoch 72
# Step 0 Loss 0.583794
# Step 100 Loss 7.79334e-05
# Step 200 Loss 8.20659e-05
# Step 300 Loss 7.63115e-05
# Step 400 Loss 8.66088e-05
# Step 500 Loss 6.64817e-05
# Step 600 Loss 6.13426e-05
# New data, epoch 73
# Step 0 Loss 0.358843
# Step 100 Loss 0.000120376
# Step 200 Loss 9.35872e-05
# Step 300 Loss 8.04357e-05
# Step 400 Loss 8.40994e-05
# Step 500 Loss 8.18827e-05
# Step 600 Loss 9.59439e-05
# New data, epoch 74
# Step 0 Loss 0.332153
# Step 100 Loss 0.000114014
# Step 200 Loss 8.65763e-05
# Step 300 Loss 9.28464e-05
# Step 400 Loss 7.31747e-05
# Step 500 Loss 8.61833e-05
# Step 600 Loss 9.52828e-05
# New data, epoch 75
# Step 0 Loss 0.633221
# Step 100 Loss 8.29017e-05
# Step 200 Loss 8.6303e-05
# Step 300 Loss 9.7739e-05
# Step 400 Loss 8.60601e-05
# Step 500 Loss 8.60303e-05
# Step 600 Loss 9.34354e-05
# New data, epoch 76
# Step 0 Loss 0.478474
# Step 100 Loss 8.84642e-05
# Step 200 Loss 0.000100542
# Step 300 Loss 8.5915e-05
# Step 400 Loss 7.0105e-05
# Step 500 Loss 9.49306e-05
# Step 600 Loss 8.92541e-05
# New data, epoch 77
# Step 0 Loss 0.187589
# Step 100 Loss 0.000102239
# Step 200 Loss 9.69716e-05
# Step 300 Loss 0.000117245
# Step 400 Loss 7.89857e-05
# Step 500 Loss 9.36262e-05
# Step 600 Loss 9.58807e-05
# New data, epoch 78
# Step 0 Loss 0.261218
# Step 100 Loss 0.000121264
# Step 200 Loss 0.000112473
# Step 300 Loss 9.31616e-05
# Step 400 Loss 0.00010622
# Step 500 Loss 7.00559e-05
# Step 600 Loss 8.771e-05
# New data, epoch 79
# Step 0 Loss 0.360326
# Step 100 Loss 7.50863e-05
# Step 200 Loss 8.10988e-05
# Step 300 Loss 6.89193e-05
# Step 400 Loss 8.09004e-05
# Step 500 Loss 7.54645e-05
# Step 600 Loss 8.13318e-05
# New data, epoch 80
# Step 0 Loss 0.354781
# Step 100 Loss 9.75021e-05
# Step 200 Loss 6.84164e-05
# Step 300 Loss 7.7212e-05
# Step 400 Loss 7.70705e-05
# Step 500 Loss 7.03775e-05
# Step 600 Loss 7.60494e-05
# New data, epoch 81
# Step 0 Loss 0.710103
# Step 100 Loss 0.000101142
# Step 200 Loss 7.19745e-05
# Step 300 Loss 0.000104216
# Step 400 Loss 8.3429e-05
# Step 500 Loss 8.383e-05
# Step 600 Loss 8.22834e-05
# New data, epoch 82
# Step 0 Loss 0.478234
# Step 100 Loss 7.6253e-05
# Step 200 Loss 6.88045e-05
# Step 300 Loss 6.60735e-05
# Step 400 Loss 6.98779e-05
# Step 500 Loss 8.24562e-05
# Step 600 Loss 7.91727e-05
# New data, epoch 83
# Step 0 Loss 0.331048
# Step 100 Loss 8.70486e-05
# Step 200 Loss 6.277e-05
# Step 300 Loss 5.99168e-05
# Step 400 Loss 8.23383e-05
# Step 500 Loss 6.02396e-05
# Step 600 Loss 7.06653e-05
# New data, epoch 84
# Step 0 Loss 0.35393
# Step 100 Loss 5.76602e-05
# Step 200 Loss 8.25077e-05
# Step 300 Loss 7.7143e-05
# Step 400 Loss 8.3323e-05
# Step 500 Loss 8.82826e-05
# Step 600 Loss 8.01311e-05
# New data, epoch 85
# Step 0 Loss 0.595885
# Step 100 Loss 7.79037e-05
# Step 200 Loss 6.88307e-05
# Step 300 Loss 7.05301e-05
# Step 400 Loss 7.83816e-05
# Step 500 Loss 8.31165e-05
# Step 600 Loss 5.64387e-05
# New data, epoch 86
# Step 0 Loss 0.211413
# Step 100 Loss 7.11549e-05
# Step 200 Loss 5.5708e-05
# Step 300 Loss 5.88733e-05
# Step 400 Loss 5.69586e-05
# Step 500 Loss 8.96856e-05
# Step 600 Loss 7.24273e-05
# New data, epoch 87
# Step 0 Loss 0.565303
# Step 100 Loss 7.17521e-05
# Step 200 Loss 6.93157e-05
# Step 300 Loss 6.79531e-05
# Step 400 Loss 7.40462e-05
# Step 500 Loss 5.53905e-05
# Step 600 Loss 6.51778e-05
# New data, epoch 88
# Step 0 Loss 0.417802
# Step 100 Loss 5.81411e-05
# Step 200 Loss 0.000103088
# Step 300 Loss 6.39593e-05
# Step 400 Loss 8.54861e-05
# Step 500 Loss 6.78416e-05
# Step 600 Loss 6.32924e-05
# New data, epoch 89
# Step 0 Loss 0.477282
# Step 100 Loss 7.44923e-05
# Step 200 Loss 7.17774e-05
# Step 300 Loss 6.5157e-05
# Step 400 Loss 7.33163e-05
# Step 500 Loss 6.0918e-05
# Step 600 Loss 6.95286e-05
# New data, epoch 90
# Step 0 Loss 0.30988
# Step 100 Loss 0.000165727
# Step 200 Loss 0.000101487
# Step 300 Loss 7.60463e-05
# Step 400 Loss 6.92126e-05
# Step 500 Loss 7.96775e-05
# Step 600 Loss 8.77558e-05
# New data, epoch 91
# Step 0 Loss 0.425166
# Step 100 Loss 6.69075e-05
# Step 200 Loss 6.56965e-05
# Step 300 Loss 5.55516e-05
# Step 400 Loss 6.62014e-05
# Step 500 Loss 6.02806e-05
# Step 600 Loss 6.02452e-05
# New data, epoch 92
# Step 0 Loss 0.279467
# Step 100 Loss 6.43139e-05
# Step 200 Loss 6.8921e-05
# Step 300 Loss 7.63377e-05
# Step 400 Loss 6.51702e-05
# Step 500 Loss 6.51338e-05
# Step 600 Loss 6.05286e-05
# New data, epoch 93
# Step 0 Loss 0.311825
# Step 100 Loss 6.90306e-05
# Step 200 Loss 5.96966e-05
# Step 300 Loss 6.75559e-05
# Step 400 Loss 5.38451e-05
# Step 500 Loss 5.05453e-05
# Step 600 Loss 6.67823e-05
# New data, epoch 94
# Step 0 Loss 0.220072
# Step 100 Loss 5.44648e-05
# Step 200 Loss 5.77722e-05
# Step 300 Loss 7.03138e-05
# Step 400 Loss 6.88068e-05
# Step 500 Loss 5.177e-05
# Step 600 Loss 5.44627e-05
# New data, epoch 95
# Step 0 Loss 0.109759
# Step 100 Loss 6.04368e-05
# Step 200 Loss 6.5888e-05
# Step 300 Loss 4.84739e-05
# Step 400 Loss 5.32184e-05
# Step 500 Loss 6.69324e-05
# Step 600 Loss 6.90946e-05
# New data, epoch 96
# Step 0 Loss 0.412458
# Step 100 Loss 0.000114265
# Step 200 Loss 7.99986e-05
# Step 300 Loss 5.352e-05
# Step 400 Loss 7.04089e-05
# Step 500 Loss 6.402e-05
# Step 600 Loss 6.74028e-05
# New data, epoch 97
# Step 0 Loss 0.0800705
# Step 100 Loss 6.046e-05
# Step 200 Loss 6.55362e-05
# Step 300 Loss 6.15453e-05
# Step 400 Loss 6.57398e-05
# Step 500 Loss 5.60147e-05
# Step 600 Loss 6.96283e-05
# New data, epoch 98
# Step 0 Loss 0.264059
# Step 100 Loss 6.92929e-05
# Step 200 Loss 6.90278e-05
# Step 300 Loss 5.24406e-05
# Step 400 Loss 7.54513e-05
# Step 500 Loss 4.94357e-05
# Step 600 Loss 6.8992e-05
# New data, epoch 99
# Step 0 Loss 0.683945
# Step 100 Loss 7.90341e-05
# Step 200 Loss 9.04261e-05
# Step 300 Loss 6.10141e-05
# Step 400 Loss 7.14829e-05
# Step 500 Loss 6.36529e-05
# Step 600 Loss 5.94194e-05

# %%
current_input = inputs_series[0]
current_input = tf.reshape(current_input, [batch_size, 1])
current_state = init_state
tf.concat([current_input, current_state], 1)
