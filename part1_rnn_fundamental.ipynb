# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15 
state_size = 4
num_classes = 2
echo_step = 3 
batch_size = 5 # number of sample trained in a iteration
num_batches = total_series_length//batch_size//truncated_backprop_length

# %%
def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

# %%
batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

init_state = tf.placeholder(tf.float32, [batch_size, state_size])

# %%
W = tf.Variable(np.random.rand(state_size+1, state_size), dtype=tf.float32)
b = tf.Variable(np.zeros((1, state_size)), dtype=tf.float32)

W2 = tf.Variable(np.random.rand(state_size, num_classes), dtype=tf.float32)
b2 = tf.Variable(np.zeros((1, num_classes)), dtype=tf.float32)

# %%
# batchX_placeholder is in shape of (batch_size, truncated_backprop_length)
# Let's say batch_size=5, and truncated_backprop_length=15
# If we unstack the batchX_placeholder, it will have 15 of (5,) tensor.
# The rnn is trained based of this 5 batches with 15 timesteps each

inputs_series = tf.unstack(batchX_placeholder, axis=1)
labels_series = tf.unstack(batchY_placeholder, axis=1)

# print(inputs_series)

# %%
# This is basically the forward pass in the RNN.
# For each input in the inputs_series, we concatenate it with the state value.
# Then, we apply the same weights W and biases b on each of these input and
# find the corresponding state value in this time series. 
current_state = init_state
states_series = []

for current_input in inputs_series:
    # (5,) -> (5,1) so as to concatenate with the state
    current_input = tf.reshape(current_input, [batch_size, 1])
    
    # Calculate the sum of affine transform
    # By concatenating those two tensors you will only use one matrix 
    # multiplication.
    input_and_state_concatenated = tf.concat([current_input, current_state], 1)
    
    next_state = tf.tanh(tf.matmul(input_and_state_concatenated, W) + b)
    states_series.append(next_state)
    current_state = next_state

# %%
# Calculating loss
logits_series = [tf.matmul(state, W2) + b2 for state in states_series]
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)\
         for logits, labels in zip(logits_series, labels_series)]

total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

# %%
# visualizing the training

def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = \
        np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = \
        np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list=[]
    
    for epoch_idx in range(num_epochs):
        x,y = generateData()
        _current_state = np.zeros((batch_size, state_size))
        
        print("New data, epoch", epoch_idx)
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length
            
            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]
            
            _total_loss, _train_step, _current_state, _predictions_series = \
            sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder: batchX,
                    batchY_placeholder: batchY,
                    init_state:_current_state
                }
            )
            
            loss_list.append(_total_loss)
            
            if batch_idx%100 == 0:
                print("Step",batch_idx,"Loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# New data, epoch 0
# Step 0 Loss 0.779243
# Step 100 Loss 0.692517
# Step 200 Loss 0.684499
# Step 300 Loss 0.691071
# Step 400 Loss 0.692685
# Step 500 Loss 0.69285
# Step 600 Loss 0.696402
# New data, epoch 1
# Step 0 Loss 0.676949
# Step 100 Loss 0.691019
# Step 200 Loss 0.716431
# Step 300 Loss 0.693147
# Step 400 Loss 0.683781
# Step 500 Loss 0.699609
# Step 600 Loss 0.694176
# New data, epoch 2
# Step 0 Loss 0.707716
# Step 100 Loss 0.701371
# Step 200 Loss 0.695249
# Step 300 Loss 0.693708
# Step 400 Loss 0.693916
# Step 500 Loss 0.695916
# Step 600 Loss 0.693768
# New data, epoch 3
# Step 0 Loss 0.686798
# Step 100 Loss 0.693999
# Step 200 Loss 0.692817
# Step 300 Loss 0.695147
# Step 400 Loss 0.69386
# Step 500 Loss 0.684763
# Step 600 Loss 0.694773
# New data, epoch 4
# Step 0 Loss 0.679678
# Step 100 Loss 0.696782
# Step 200 Loss 0.694253
# Step 300 Loss 0.692837
# Step 400 Loss 0.693228
# Step 500 Loss 0.693985
# Step 600 Loss 0.692994
# New data, epoch 5
# Step 0 Loss 0.695039
# Step 100 Loss 0.691983
# Step 200 Loss 0.696284
# Step 300 Loss 0.692775
# Step 400 Loss 0.696055
# Step 500 Loss 0.693336
# Step 600 Loss 0.692759
# New data, epoch 6
# Step 0 Loss 0.692097
# Step 100 Loss 0.687621
# Step 200 Loss 0.704829
# Step 300 Loss 0.693861
# Step 400 Loss 0.688059
# Step 500 Loss 0.693819
# Step 600 Loss 0.692379
# New data, epoch 7
# Step 0 Loss 0.706466
# Step 100 Loss 0.698294
# Step 200 Loss 0.694307
# Step 300 Loss 0.699048
# Step 400 Loss 0.693183
# Step 500 Loss 0.693754
# Step 600 Loss 0.688222
# New data, epoch 8
# Step 0 Loss 0.685898
# Step 100 Loss 0.691793
# Step 200 Loss 0.697066
# Step 300 Loss 0.695156
# Step 400 Loss 0.693936
# Step 500 Loss 0.693866
# Step 600 Loss 0.697565
# New data, epoch 9
# Step 0 Loss 0.709646
# Step 100 Loss 0.696469
# Step 200 Loss 0.698354
# Step 300 Loss 0.690392
# Step 400 Loss 0.693582
# Step 500 Loss 0.692074
# Step 600 Loss 0.694652
# New data, epoch 10
# Step 0 Loss 0.692799
# Step 100 Loss 0.693746
# Step 200 Loss 0.70013
# Step 300 Loss 0.693263
# Step 400 Loss 0.701249
# Step 500 Loss 0.692927
# Step 600 Loss 0.693467
# New data, epoch 11
# Step 0 Loss 0.687159
# Step 100 Loss 0.692786
# Step 200 Loss 0.698467
# Step 300 Loss 0.695759
# Step 400 Loss 0.689882
# Step 500 Loss 0.687114
# Step 600 Loss 0.6974
# New data, epoch 12
# Step 0 Loss 0.690488
# Step 100 Loss 0.69924
# Step 200 Loss 0.693826
# Step 300 Loss 0.690145
# Step 400 Loss 0.693494
# Step 500 Loss 0.171372
# Step 600 Loss 0.0516104
# New data, epoch 13
# Step 0 Loss 0.271807
# Step 100 Loss 0.0260099
# Step 200 Loss 0.0177425
# Step 300 Loss 0.0148114
# Step 400 Loss 0.0123916
# Step 500 Loss 0.0107143
# Step 600 Loss 0.00926777
# New data, epoch 14
# Step 0 Loss 0.159178
# Step 100 Loss 0.00728746
# Step 200 Loss 0.00573442
# Step 300 Loss 0.00617372
# Step 400 Loss 0.00581158
# Step 500 Loss 0.00472538
# Step 600 Loss 0.00540647
# New data, epoch 15
# Step 0 Loss 0.171354
# Step 100 Loss 0.00449894
# Step 200 Loss 0.00376494
# Step 300 Loss 0.00326615
# Step 400 Loss 0.00378047
# Step 500 Loss 0.00462774
# Step 600 Loss 0.00350101
# New data, epoch 16
# Step 0 Loss 0.40897
# Step 100 Loss 0.00335246
# Step 200 Loss 0.00376341
# Step 300 Loss 0.00291804
# Step 400 Loss 0.00236441
# Step 500 Loss 0.00226696
# Step 600 Loss 0.00234462
# New data, epoch 17
# Step 0 Loss 0.136924
# Step 100 Loss 0.00412974
# Step 200 Loss 0.00302124
# Step 300 Loss 0.00295308
# Step 400 Loss 0.00239445
# Step 500 Loss 0.00259327
# Step 600 Loss 0.00231717
# New data, epoch 18
# Step 0 Loss 0.265067
# Step 100 Loss 0.00212324
# Step 200 Loss 0.00237152
# Step 300 Loss 0.00177774
# Step 400 Loss 0.00215012
# Step 500 Loss 0.00175675
# Step 600 Loss 0.00189209
# New data, epoch 19
# Step 0 Loss 0.234298
# Step 100 Loss 0.00248206
# Step 200 Loss 0.00155391
# Step 300 Loss 0.00190871
# Step 400 Loss 0.0015622
# Step 500 Loss 0.00179323
# Step 600 Loss 0.00155212
# New data, epoch 20
# Step 0 Loss 0.358659
# Step 100 Loss 0.00435705
# Step 200 Loss 0.00176646
# Step 300 Loss 0.00127871
# Step 400 Loss 0.00138067
# Step 500 Loss 0.00132113
# Step 600 Loss 0.00113956
# New data, epoch 21
# Step 0 Loss 0.240193
# Step 100 Loss 0.00196642
# Step 200 Loss 0.00147432
# Step 300 Loss 0.00150546
# Step 400 Loss 0.0011298
# Step 500 Loss 0.00108715
# Step 600 Loss 0.00106357
# New data, epoch 22
# Step 0 Loss 0.406588
# Step 100 Loss 0.00150749
# Step 200 Loss 0.00153107
# Step 300 Loss 0.00139125
# Step 400 Loss 0.00115075
# Step 500 Loss 0.00114492
# Step 600 Loss 0.00106067
# New data, epoch 23
# Step 0 Loss 0.308131
# Step 100 Loss 0.00201435
# Step 200 Loss 0.00135079
# Step 300 Loss 0.00133261
# Step 400 Loss 0.00142367
# Step 500 Loss 0.00117171
# Step 600 Loss 0.00105612
# New data, epoch 24
# Step 0 Loss 0.11732
# Step 100 Loss 0.00118158
# Step 200 Loss 0.00102681
# Step 300 Loss 0.000956543
# Step 400 Loss 0.00103525
# Step 500 Loss 0.00101293
# Step 600 Loss 0.000761808
# New data, epoch 25
# Step 0 Loss 0.28302
# Step 100 Loss 0.000877381
# Step 200 Loss 0.000827757
# Step 300 Loss 0.000907787
# Step 400 Loss 0.000857559
# Step 500 Loss 0.000775274
# Step 600 Loss 0.000752589
# New data, epoch 26
# Step 0 Loss 0.33347
# Step 100 Loss 0.000806242
# Step 200 Loss 0.000738241
# Step 300 Loss 0.000712657
# Step 400 Loss 0.00081633
# Step 500 Loss 0.000707256
# Step 600 Loss 0.000832678
# New data, epoch 27
# Step 0 Loss 0.266779
# Step 100 Loss 0.000804758
# Step 200 Loss 0.000727907
# Step 300 Loss 0.000823946
# Step 400 Loss 0.000640379
# Step 500 Loss 0.00078348
# Step 600 Loss 0.000826396
# New data, epoch 28
# Step 0 Loss 0.530264
# Step 100 Loss 0.000852786
# Step 200 Loss 0.000650369
# Step 300 Loss 0.000639704
# Step 400 Loss 0.000706068
# Step 500 Loss 0.000627161
# Step 600 Loss 0.000601753
# New data, epoch 29
# Step 0 Loss 0.244767
# Step 100 Loss 0.000864509
# Step 200 Loss 0.000534667
# Step 300 Loss 0.000706739
# Step 400 Loss 0.000572002
# Step 500 Loss 0.000558926
# Step 600 Loss 0.00057257
# New data, epoch 30
# Step 0 Loss 0.185125
# Step 100 Loss 0.000644249
# Step 200 Loss 0.000642613
# Step 300 Loss 0.000617071
# Step 400 Loss 0.000686651
# Step 500 Loss 0.000674153
# Step 600 Loss 0.000645059
# New data, epoch 31
# Step 0 Loss 0.228914
# Step 100 Loss 0.000644583
# Step 200 Loss 0.000662553
# Step 300 Loss 0.000604623
# Step 400 Loss 0.000640849
# Step 500 Loss 0.000741644
# Step 600 Loss 0.000619715
# New data, epoch 32
# Step 0 Loss 0.225652
# Step 100 Loss 0.000598056
# Step 200 Loss 0.000530939
# Step 300 Loss 0.00066949
# Step 400 Loss 0.000633061
# Step 500 Loss 0.000554143
# Step 600 Loss 0.000413673
# New data, epoch 33
# Step 0 Loss 0.481538
# Step 100 Loss 0.000469775
# Step 200 Loss 0.000433853
# Step 300 Loss 0.000537458
# Step 400 Loss 0.000518776
# Step 500 Loss 0.00076674
# Step 600 Loss 0.000507505
# New data, epoch 34
# Step 0 Loss 0.231916
# Step 100 Loss 0.000604114
# Step 200 Loss 0.000439659
# Step 300 Loss 0.000650674
# Step 400 Loss 0.000609923
# Step 500 Loss 0.000497702
# Step 600 Loss 0.00057259
# New data, epoch 35
# Step 0 Loss 0.192586
# Step 100 Loss 0.00065322
# Step 200 Loss 0.000778141
# Step 300 Loss 0.000551475
# Step 400 Loss 0.000538035
# Step 500 Loss 0.000670462
# Step 600 Loss 0.000534997
# New data, epoch 36
# Step 0 Loss 0.176274
# Step 100 Loss 0.000497247
# Step 200 Loss 0.000488382
# Step 300 Loss 0.000503751
# Step 400 Loss 0.000538445
# Step 500 Loss 0.000433131
# Step 600 Loss 0.00045261
# New data, epoch 37
# Step 0 Loss 0.131922
# Step 100 Loss 0.000476612
# Step 200 Loss 0.000402291
# Step 300 Loss 0.00051049
# Step 400 Loss 0.000475822
# Step 500 Loss 0.000464109
# Step 600 Loss 0.000482728
# New data, epoch 38
# Step 0 Loss 0.232898
# Step 100 Loss 0.000462138
# Step 200 Loss 0.000495781
# Step 300 Loss 0.000467295
# Step 400 Loss 0.000411819
# Step 500 Loss 0.000521206
# Step 600 Loss 0.000364784
# New data, epoch 39
# Step 0 Loss 0.252417
# Step 100 Loss 0.000440708
# Step 200 Loss 0.000445455
# Step 300 Loss 0.000439501
# Step 400 Loss 0.000614177
# Step 500 Loss 0.000468913
# Step 600 Loss 0.000368033
# New data, epoch 40
# Step 0 Loss 0.248679
# Step 100 Loss 0.000462617
# Step 200 Loss 0.000390192
# Step 300 Loss 0.000598047
# Step 400 Loss 0.000421338
# Step 500 Loss 0.00034351
# Step 600 Loss 0.000374673
# New data, epoch 41
# Step 0 Loss 0.437191
# Step 100 Loss 0.000569663
# Step 200 Loss 0.000487303
# Step 300 Loss 0.000419292
# Step 400 Loss 0.000388294
# Step 500 Loss 0.000427455
# Step 600 Loss 0.000365458
# New data, epoch 42
# Step 0 Loss 0.324923
# Step 100 Loss 0.000410536
# Step 200 Loss 0.000429864
# Step 300 Loss 0.000370554
# Step 400 Loss 0.000291689
# Step 500 Loss 0.000358474
# Step 600 Loss 0.00034429
# New data, epoch 43
# Step 0 Loss 0.233908
# Step 100 Loss 0.00029478
# Step 200 Loss 0.000422242
# Step 300 Loss 0.000317485
# Step 400 Loss 0.000389853
# Step 500 Loss 0.000392919
# Step 600 Loss 0.000310019
# New data, epoch 44
# Step 0 Loss 0.307448
# Step 100 Loss 0.000462395
# Step 200 Loss 0.000628021
# Step 300 Loss 0.000724545
# Step 400 Loss 0.000713052
# Step 500 Loss 0.000482593
# Step 600 Loss 0.000523843
# New data, epoch 45
# Step 0 Loss 0.428869
# Step 100 Loss 0.000669128
# Step 200 Loss 0.000560497
# Step 300 Loss 0.000483929
# Step 400 Loss 0.000776429
# Step 500 Loss 0.000524135
# Step 600 Loss 0.000618352
# New data, epoch 46
# Step 0 Loss 0.343579
# Step 100 Loss 0.000322558
# Step 200 Loss 0.000365446
# Step 300 Loss 0.000344555
# Step 400 Loss 0.000367298
# Step 500 Loss 0.000460193
# Step 600 Loss 0.000431648
# New data, epoch 47
# Step 0 Loss 0.325177
# Step 100 Loss 0.000333243
# Step 200 Loss 0.000326479
# Step 300 Loss 0.000330923
# Step 400 Loss 0.000297434
# Step 500 Loss 0.000357987
# Step 600 Loss 0.000379353
# New data, epoch 48
# Step 0 Loss 0.192902
# Step 100 Loss 0.00035147
# Step 200 Loss 0.000308636
# Step 300 Loss 0.000421015
# Step 400 Loss 0.000366402
# Step 500 Loss 0.000303357
# Step 600 Loss 0.000492095
# New data, epoch 49
# Step 0 Loss 0.360262
# Step 100 Loss 0.000339228
# Step 200 Loss 0.000267881
# Step 300 Loss 0.000343755
# Step 400 Loss 0.000334664
# Step 500 Loss 0.000351582
# Step 600 Loss 0.000300714
# New data, epoch 50
# Step 0 Loss 0.140751
# Step 100 Loss 0.000257677
# Step 200 Loss 0.000325214
# Step 300 Loss 0.000413884
# Step 400 Loss 0.000335995
# Step 500 Loss 0.000304649
# Step 600 Loss 0.000266467
# New data, epoch 51
# Step 0 Loss 0.215913
# Step 100 Loss 0.000377695
# Step 200 Loss 0.000325
# Step 300 Loss 0.000363849
# Step 400 Loss 0.000337731
# Step 500 Loss 0.000299132
# Step 600 Loss 0.000272891
# New data, epoch 52
# Step 0 Loss 0.418601
# Step 100 Loss 0.00026731
# Step 200 Loss 0.000334712
# Step 300 Loss 0.000340298
# Step 400 Loss 0.000306961
# Step 500 Loss 0.000277922
# Step 600 Loss 0.000316535
# New data, epoch 53
# Step 0 Loss 0.558288
# Step 100 Loss 0.000236049
# Step 200 Loss 0.000245466
# Step 300 Loss 0.000294398
# Step 400 Loss 0.000293762
# Step 500 Loss 0.000257172
# Step 600 Loss 0.000365437
# New data, epoch 54
# Step 0 Loss 0.183585
# Step 100 Loss 0.000319644
# Step 200 Loss 0.000293285
# Step 300 Loss 0.000235113
# Step 400 Loss 0.000239839
# Step 500 Loss 0.000288028
# Step 600 Loss 0.00035926
# New data, epoch 55
# Step 0 Loss 0.284977
# Step 100 Loss 0.000229476
# Step 200 Loss 0.00022999
# Step 300 Loss 0.000342632
# Step 400 Loss 0.000291759
# Step 500 Loss 0.000183975
# Step 600 Loss 0.000300576
# New data, epoch 56
# Step 0 Loss 0.287129
# Step 100 Loss 0.000339742
# Step 200 Loss 0.000286821
# Step 300 Loss 0.000248213
# Step 400 Loss 0.00029226
# Step 500 Loss 0.000276142
# Step 600 Loss 0.000329765
# New data, epoch 57
# Step 0 Loss 0.199591
# Step 100 Loss 0.000285501
# Step 200 Loss 0.000289455
# Step 300 Loss 0.000238
# Step 400 Loss 0.00025209
# Step 500 Loss 0.000252001
# Step 600 Loss 0.000251313
# New data, epoch 58
# Step 0 Loss 0.121997
# Step 100 Loss 0.000220696
# Step 200 Loss 0.000231322
# Step 300 Loss 0.000249164
# Step 400 Loss 0.000194754
# Step 500 Loss 0.000405255
# Step 600 Loss 0.000240144
# New data, epoch 59
# Step 0 Loss 0.229267
# Step 100 Loss 0.000339539
# Step 200 Loss 0.000343884
# Step 300 Loss 0.000332614
# Step 400 Loss 0.000316863
# Step 500 Loss 0.00029577
# Step 600 Loss 0.000280096
# New data, epoch 60
# Step 0 Loss 0.113902
# Step 100 Loss 0.000289011
# Step 200 Loss 0.000398821
# Step 300 Loss 0.000249503
# Step 400 Loss 0.000266376
# Step 500 Loss 0.000281631
# Step 600 Loss 0.000258055
# New data, epoch 61
# Step 0 Loss 0.252984
# Step 100 Loss 0.000210948
# Step 200 Loss 0.000264257
# Step 300 Loss 0.000227052
# Step 400 Loss 0.000230725
# Step 500 Loss 0.000278123
# Step 600 Loss 0.000242249
# New data, epoch 62
# Step 0 Loss 0.150941
# Step 100 Loss 0.000241559
# Step 200 Loss 0.000274366
# Step 300 Loss 0.000205318
# Step 400 Loss 0.000237179
# Step 500 Loss 0.000233912
# Step 600 Loss 0.000221116
# New data, epoch 63
# Step 0 Loss 0.261293
# Step 100 Loss 0.00031044
# Step 200 Loss 0.00029726
# Step 300 Loss 0.000208548
# Step 400 Loss 0.000256262
# Step 500 Loss 0.000227118
# Step 600 Loss 0.000208286
# New data, epoch 64
# Step 0 Loss 0.302469
# Step 100 Loss 0.00017197
# Step 200 Loss 0.000221006
# Step 300 Loss 0.000196905
# Step 400 Loss 0.000226654
# Step 500 Loss 0.000218379
# Step 600 Loss 0.000228643
# New data, epoch 65
# Step 0 Loss 0.126345
# Step 100 Loss 0.000208019
# Step 200 Loss 0.000245914
# Step 300 Loss 0.000180168
# Step 400 Loss 0.000219518
# Step 500 Loss 0.000250912
# Step 600 Loss 0.000277629
# New data, epoch 66
# Step 0 Loss 0.121437
# Step 100 Loss 0.000176201
# Step 200 Loss 0.00020091
# Step 300 Loss 0.00022063
# Step 400 Loss 0.000200068
# Step 500 Loss 0.00021021
# Step 600 Loss 0.000234413
# New data, epoch 67
# Step 0 Loss 0.223513
# Step 100 Loss 0.000254194
# Step 200 Loss 0.00026388
# Step 300 Loss 0.000188052
# Step 400 Loss 0.000181841
# Step 500 Loss 0.000231256
# Step 600 Loss 0.000172119
# New data, epoch 68
# Step 0 Loss 0.546395
# Step 100 Loss 0.000200752
# Step 200 Loss 0.000177167
# Step 300 Loss 0.000236295
# Step 400 Loss 0.000223184
# Step 500 Loss 0.000193216
# Step 600 Loss 0.000237678
# New data, epoch 69
# Step 0 Loss 0.278734
# Step 100 Loss 0.000161448
# Step 200 Loss 0.000190492
# Step 300 Loss 0.00018605
# Step 400 Loss 0.00015547
# Step 500 Loss 0.000195077
# Step 600 Loss 0.00028273
# New data, epoch 70
# Step 0 Loss 0.183534
# Step 100 Loss 0.000229529
# Step 200 Loss 0.000220263
# Step 300 Loss 0.00020575
# Step 400 Loss 0.000246258
# Step 500 Loss 0.000205704
# Step 600 Loss 0.000171431
# New data, epoch 71
# Step 0 Loss 0.369334
# Step 100 Loss 0.000223279
# Step 200 Loss 0.000195344
# Step 300 Loss 0.000279575
# Step 400 Loss 0.000180713
# Step 500 Loss 0.000200396
# Step 600 Loss 0.000176462
# New data, epoch 72
# Step 0 Loss 0.193375
# Step 100 Loss 0.000195285
# Step 200 Loss 0.000218505
# Step 300 Loss 0.000169365
# Step 400 Loss 0.000191366
# Step 500 Loss 0.000194111
# Step 600 Loss 0.00021321
# New data, epoch 73
# Step 0 Loss 0.153183
# Step 100 Loss 0.000195834
# Step 200 Loss 0.000181105
# Step 300 Loss 0.000154329
# Step 400 Loss 0.000171404
# Step 500 Loss 0.00022431
# Step 600 Loss 0.000198274
# New data, epoch 74
# Step 0 Loss 0.130622
# Step 100 Loss 0.000177621
# Step 200 Loss 0.000210434
# Step 300 Loss 0.000186589
# Step 400 Loss 0.00017519
# Step 500 Loss 0.000193183
# Step 600 Loss 0.00012779
# New data, epoch 75
# Step 0 Loss 0.226939
# Step 100 Loss 0.000215703
# Step 200 Loss 0.000200375
# Step 300 Loss 0.000254869
# Step 400 Loss 0.000257411
# Step 500 Loss 0.000223803
# Step 600 Loss 0.000225648
# New data, epoch 76
# Step 0 Loss 0.140366
# Step 100 Loss 0.000222318
# Step 200 Loss 0.000218598
# Step 300 Loss 0.000274065
# Step 400 Loss 0.000177334
# Step 500 Loss 0.000154738
# Step 600 Loss 0.000204524
# New data, epoch 77
# Step 0 Loss 0.301437
# Step 100 Loss 0.000169932
# Step 200 Loss 0.000176951
# Step 300 Loss 0.000156361
# Step 400 Loss 0.000191185
# Step 500 Loss 0.000162605
# Step 600 Loss 0.000197896
# New data, epoch 78
# Step 0 Loss 0.376641
# Step 100 Loss 0.000206227
# Step 200 Loss 0.000247058
# Step 300 Loss 0.000187417
# Step 400 Loss 0.000162716
# Step 500 Loss 0.000189296
# Step 600 Loss 0.000214673
# New data, epoch 79
# Step 0 Loss 0.446842
# Step 100 Loss 0.000162593
# Step 200 Loss 0.000161892
# Step 300 Loss 0.000141062
# Step 400 Loss 0.00022427
# Step 500 Loss 0.000188149
# Step 600 Loss 0.000180335
# New data, epoch 80
# Step 0 Loss 0.254933
# Step 100 Loss 0.000212986
# Step 200 Loss 0.000171412
# Step 300 Loss 0.000181278
# Step 400 Loss 0.000170965
# Step 500 Loss 0.000162981
# Step 600 Loss 0.000188004
# New data, epoch 81
# Step 0 Loss 0.220301
# Step 100 Loss 0.000197203
# Step 200 Loss 0.000210043
# Step 300 Loss 0.000221321
# Step 400 Loss 0.000175232
# Step 500 Loss 0.0001347
# Step 600 Loss 0.000156456
# New data, epoch 82
# Step 0 Loss 0.172885
# Step 100 Loss 0.00013968
# Step 200 Loss 0.000175438
# Step 300 Loss 0.000189172
# Step 400 Loss 0.000161026
# Step 500 Loss 0.000162198
# Step 600 Loss 0.000154985
# New data, epoch 83
# Step 0 Loss 0.133073
# Step 100 Loss 0.000142054
# Step 200 Loss 0.000157097
# Step 300 Loss 0.000251275
# Step 400 Loss 0.000158656
# Step 500 Loss 0.000214336
# Step 600 Loss 0.000200297
# New data, epoch 84
# Step 0 Loss 0.248956
# Step 100 Loss 0.00018516
# Step 200 Loss 0.000163842
# Step 300 Loss 0.000164799
# Step 400 Loss 0.000185708
# Step 500 Loss 0.000178888
# Step 600 Loss 0.000145851
# New data, epoch 85
# Step 0 Loss 0.219886
# Step 100 Loss 0.000150088
# Step 200 Loss 0.000155367
# Step 300 Loss 0.000156797
# Step 400 Loss 0.000171556
# Step 500 Loss 0.000180135
# Step 600 Loss 0.000139262
# New data, epoch 86
# Step 0 Loss 0.217757
# Step 100 Loss 0.000144824
# Step 200 Loss 0.00017077
# Step 300 Loss 0.000147909
# Step 400 Loss 0.00015944
# Step 500 Loss 0.000190815
# Step 600 Loss 0.000132544
# New data, epoch 87
# Step 0 Loss 0.170364
# Step 100 Loss 0.00016323
# Step 200 Loss 0.000170581
# Step 300 Loss 0.000215612
# Step 400 Loss 0.000195314
# Step 500 Loss 0.000170583
# Step 600 Loss 0.000151182
# New data, epoch 88
# Step 0 Loss 0.131749
# Step 100 Loss 0.000137335
# Step 200 Loss 0.000167277
# Step 300 Loss 0.000160895
# Step 400 Loss 0.000173527
# Step 500 Loss 0.000156889
# Step 600 Loss 0.000144567
# New data, epoch 89
# Step 0 Loss 0.441153
# Step 100 Loss 0.000139095
# Step 200 Loss 0.000150961
# Step 300 Loss 0.000137259
# Step 400 Loss 0.00014091
# Step 500 Loss 0.000151695
# Step 600 Loss 0.00014887
# New data, epoch 90
# Step 0 Loss 0.22799
# Step 100 Loss 0.000144982
# Step 200 Loss 0.000152236
# Step 300 Loss 0.000105235
# Step 400 Loss 0.000143204
# Step 500 Loss 0.000168673
# Step 600 Loss 0.000137616
# New data, epoch 91
# Step 0 Loss 0.265529
# Step 100 Loss 0.000274311
# Step 200 Loss 0.000169533
# Step 300 Loss 0.000190435
# Step 400 Loss 0.000169423
# Step 500 Loss 0.000173458
# Step 600 Loss 0.000202886
# New data, epoch 92
# Step 0 Loss 0.210128
# Step 100 Loss 0.000138207
# Step 200 Loss 0.000148959
# Step 300 Loss 0.000130995
# Step 400 Loss 0.000157273
# Step 500 Loss 0.00016678
# Step 600 Loss 0.000163326
# New data, epoch 93
# Step 0 Loss 0.334069
# Step 100 Loss 0.000142148
# Step 200 Loss 0.00015145
# Step 300 Loss 0.000186996
# Step 400 Loss 0.000177496
# Step 500 Loss 0.000160913
# Step 600 Loss 0.000196732
# New data, epoch 94
# Step 0 Loss 0.193732
# Step 100 Loss 0.000140421
# Step 200 Loss 0.000186749
# Step 300 Loss 0.000139397
# Step 400 Loss 0.00016938
# Step 500 Loss 0.000152541
# Step 600 Loss 0.000130598
# New data, epoch 95
# Step 0 Loss 0.224653
# Step 100 Loss 0.000148066
# Step 200 Loss 0.000199522
# Step 300 Loss 0.000158415
# Step 400 Loss 0.000188691
# Step 500 Loss 0.000197458
# Step 600 Loss 0.000166236
# New data, epoch 96
# Step 0 Loss 0.169533
# Step 100 Loss 0.000176233
# Step 200 Loss 0.000210285
# Step 300 Loss 0.000159833
# Step 400 Loss 0.000161799
# Step 500 Loss 0.000142871
# Step 600 Loss 0.000150389
# New data, epoch 97
# Step 0 Loss 0.389646
# Step 100 Loss 0.00016428
# Step 200 Loss 0.000127391
# Step 300 Loss 0.000149003
# Step 400 Loss 0.000170063
# Step 500 Loss 0.000142853
# Step 600 Loss 0.00015603
# New data, epoch 98
# Step 0 Loss 0.135207
# Step 100 Loss 0.000159446
# Step 200 Loss 0.000137671
# Step 300 Loss 0.000187748
# Step 400 Loss 0.000185858
# Step 500 Loss 0.000166368
# Step 600 Loss 0.000202757
# New data, epoch 99
# Step 0 Loss 0.315715
# Step 100 Loss 0.000125616
# Step 200 Loss 0.000163186
# Step 300 Loss 9.5572e-05
# Step 400 Loss 0.000143745
# Step 500 Loss 0.000113789
# Step 600 Loss 0.000135014

# %%
current_input = inputs_series[0]
current_input = tf.reshape(current_input, [batch_size, 1])
current_state = init_state
tf.concat([current_input, current_state], 1)
